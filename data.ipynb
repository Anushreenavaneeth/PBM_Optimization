# %%
import pandas as pd

# Read the Orange Book TXT file
df = pd.read_csv("G:\\PMS_Optimization\\EOBZIP_2026_06\\products.txt", sep="~", dtype=str)

# Save as CSV
df.to_csv("products.csv", index=False)

print("Conversion completed!")
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Conversion completed!
# Rows: 48502
# Columns: 14

# %%
df.isnull().sum()
# Out:
# Ingredient                 0
# DF;Route                   0
# Trade_Name                 0
# Applicant                  0
# Strength                  65
# Appl_Type                  0
# Appl_No                    0
# Product_No                 0
# TE_Code                26649
# Approval_Date              0
# RLD                        0
# RS                         0
# Type                       0
# Applicant_Full_Name        0
# dtype: int64

# %%
df = pd.read_csv("orange_book_products.csv")

print(df.head())
# Out:
#                   Ingredient               DF;Route              Trade_Name  \
# 0                 BUDESONIDE   AEROSOL, FOAM;RECTAL              BUDESONIDE
# 1                 BUDESONIDE   AEROSOL, FOAM;RECTAL                  UCERIS
# 2  MINOCYCLINE HYDROCHLORIDE  AEROSOL, FOAM;TOPICAL                  AMZEEQ
# 3               AZELAIC ACID  AEROSOL, FOAM;TOPICAL            AZELAIC ACID
# 4     BETAMETHASONE VALERATE  AEROSOL, FOAM;TOPICAL  BETAMETHASONE VALERATE
#
#               Applicant       Strength Appl_Type  Appl_No  Product_No TE_Code  \
# 0        PADAGIS ISRAEL  2MG/ACTUATION         A   215328           1      AB
# 1                 SALIX  2MG/ACTUATION         N   205613           1      AB
# 2               JOURNEY     EQ 4% BASE         N   212379           1     NaN
# 3  AUROBINDO PHARMA USA            15%         A   210928           1     NaN
# 4               ALEMBIC          0.12%         A   215832           1      AB
#
# ...

# %%
print(df.shape)
# Out:
# (48502, 14)

# %%
print(df.columns.tolist())
# Out:
# ['Ingredient', 'DF;Route', 'Trade_Name', 'Applicant', 'Strength', 'Appl_Type', 'Appl_No', 'Product_No', 'TE_Code', 'Approval_Date', 'RLD', 'RS', 'Type', 'Applicant_Full_Name']

# %%
print(df["TE_Code"].value_counts(dropna=False))
# Out:
# TE_Code
# NaN                26649
# AB                 14894
# AP                  3781
# AA                  1043
# AB1                  588
# AT                   509
# AB2                  300
# AB3                  129
# AN                   129
# AB1,AB2,AB3,AB4       72
# AO                    71
# AP1                   67
# BX                    60
# AT1                   43
# AP2                   37
# AB1,AB2,AB3           36
# AB4                   30
# AT2                   21
# AB1,AB2               12
# AB1,AB3               11
# AT3                    9
# BP                     5
# AP3                    2
# BD                     2
# BS                     1
# BC                     1
# Name: count, dtype: int64

# %%
patent = pd.read_csv("G:\\PMS_Optimization\\EOBZIP_2026_06\\patent.txt", sep="~", dtype=str)
patent.to_csv("patent.csv", index=False)



exclusivity = pd.read_csv("G:\\PMS_Optimization\\EOBZIP_2026_06\\exclusivity.txt", sep="~", dtype=str)
exclusivity.to_csv("exclusivity.csv", index=False)
